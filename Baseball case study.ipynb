# %% [markdown]
# # Baseball Case Study

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('baseball_case_study.csv')

# %%
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %% [raw]
# There are 30 rows and 17 columns

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# # Checking the datatypes of the columns

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There are no null values present in the data set

# %% [markdown]
# # Heatmap for the representation of null values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The haetmap also shows the presence of no null values

# %% [markdown]
# # Dataframe Description

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
# This problem is a regression problem and our target variable is Number of predicted wins(W)

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %% [markdown]
# High standard devition are present in AB,SO,RA and ER column which indicates that the data is spread too much and the range is high
#
# BB,SB,ER,RA ,Ehave mean greater than median.It means the variables in these columns have right skewed data and the difference between 75th percentileand max is also high which indicates the presence of outliers.

# %% [markdown]
# # Outliers

# %% [markdown]
# Using box plot to check the presence of outliers

# %%
df['W'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'W'column

# %%
df['R'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in 'R'column

# %%
df['AB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'AB'column

# %%
df['H'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'H'column

# %%
df['2B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in '2B'column

# %%
df['3B'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in '3B'column

# %%
df['HR'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'HR'column

# %%
df['BB'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'BB'column

# %%
df['SO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'SO'column

# %% [markdown]
# df['SB'].plot.box()

# %% [markdown]
# No outliers are present in 'SB'column

# %%
df['RA'].plot.box()
# Out:
# <AxesSubplot:>

# %%
No outliers are present in 'RA'column
# Out:
#   File "<ipython-input-103-72a0ce1c7256>", line 1
#     No outliers are present in 'RA'column
#        ^
# SyntaxError: invalid syntax

# %%
df['ER'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'ER'column

# %%
df['ERA'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in 'ERA'column

# %%
df['CG'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in 'CG'column

# %%
df['SHO'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in 'SHO'column

# %%
df['SV'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in 'SV'column

# %%
df['E'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in 'E'column

# %% [markdown]
# Collective representation of outliers of all the columns using box plot

# %%
df.plot(kind='box',subplots=True,layout=(2,10))
# Out:
# W         AxesSubplot(0.125,0.536818;0.065678x0.343182)
# R      AxesSubplot(0.203814,0.536818;0.065678x0.343182)
# AB     AxesSubplot(0.282627,0.536818;0.065678x0.343182)
# H      AxesSubplot(0.361441,0.536818;0.065678x0.343182)
# 2B     AxesSubplot(0.440254,0.536818;0.065678x0.343182)
# 3B     AxesSubplot(0.519068,0.536818;0.065678x0.343182)
# HR     AxesSubplot(0.597881,0.536818;0.065678x0.343182)
# BB     AxesSubplot(0.676695,0.536818;0.065678x0.343182)
# SO     AxesSubplot(0.755508,0.536818;0.065678x0.343182)
# SB     AxesSubplot(0.834322,0.536818;0.065678x0.343182)
# RA           AxesSubplot(0.125,0.125;0.065678x0.343182)
# ER        AxesSubplot(0.203814,0.125;0.065678x0.343182)
# ERA       AxesSubplot(0.282627,0.125;0.065678x0.343182)
# CG        AxesSubplot(0.361441,0.125;0.065678x0.343182)
# SHO       AxesSubplot(0.440254,0.125;0.065678x0.343182)
# SV        AxesSubplot(0.519068,0.125;0.065678x0.343182)
# E         AxesSubplot(0.597881,0.125;0.065678x0.343182)
# ...

# %% [markdown]
# From the above outcome we can see that the column'E' has the highest number of outliers.Columns'R','ERA','SHO','SV' have less no of outliers and columns 'W','AB','H','2B','3B','HR','BB','SO','SB','ER','CG'have no outliers present.

# %% [markdown]
# Removal of outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# array([[1.36540860e+00, 6.19077968e-01, 8.47731264e-01, 1.66368512e+00,
#         1.42017307e+00, 1.04119304e+00, 7.87298598e-01, 1.53490242e+00,
#         2.69762957e+00, 9.13883291e-01, 6.66233927e-01, 5.05110079e-01,
#         5.06955186e-01, 5.39806195e-01, 8.14628593e-01, 1.67160651e+00,
#         4.61469635e-01],
#        [1.97838300e-01, 1.34431656e-01, 7.11093535e-01, 9.70680764e-01,
#         1.27403389e-01, 1.23580856e+00, 2.43966683e-01, 5.36591904e-01,
#         1.54878442e-01, 6.01825582e-01, 1.65970766e-01, 2.48929848e-01,
#         2.54597523e-01, 5.39806195e-01, 1.72800005e-01, 2.49879323e-01,
#         6.07196888e-01],
#        [3.24325082e-03, 3.32905860e-01, 1.11523330e+00, 1.51891367e-01,
#         1.58879521e+00, 2.23807850e-01, 7.23377196e-01, 1.13914361e+00,
#         8.93981893e-01, 1.11449182e-01, 6.80339091e-01, 7.51623132e-01,
#         6.41346840e-01, 2.77264091e+00, 3.20914294e-01, 6.54856158e-01,
#         1.11724227e+00],
# ...

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5]), array([1]))

# %%
z[5][1]
# Out:
# 3.5096470447193067

# %%
z[1][1]
# Out:
# 0.1344316556665456

# %%
#extracting the data points that are in the range of (-3,3)
df_new=df[(z<3).all(axis=1)]
print(df.shape)
print(df_new.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# # Percentage of data loss:

# %%
#percentage of data loss
loss_percent=(30-29)/30*100
print(loss_percent)
# Out:
# 3.3333333333333335

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Skewness threshold is taken as +/-0.65 . Columns which are having skewness are:
#     1)R
#     2)H
#     3)CG
#     4)SV
#     5)E

# %% [markdown]
# Graphical Representation of Skewness

# %%
df['W'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['R'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is high

# %%
df['AB'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['H'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is above are threshold value of +/-0.65 hence has to be considered.

# %%
df['2B'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['3B'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['HR'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['BB'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['SO'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['SB'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['RA'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['ER'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['ERA'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected

# %%
df['CG'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is above the threshold value of +/-0.65 and hence has to be considered.

# %%
df['SHO'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is below the threshold value of +/-0.65 hence can be neglected.

# %%
df['SV'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is above the threshold value of +/-0.65 and hence has to be considered.

# %%
df['E'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness of this column is above the threshold value of +/-0.65 and hence has to be considered.

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['R'])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %% [markdown]
# The data of this column is not normalized.The buliding blocks are out of the normalized curve.

# %%
sns.distplot(df['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %% [markdown]
# The data of this column is not normalized.The buliding blocks are out of the normalized curve.

# %%
sns.distplot(df['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %% [markdown]
# The data of this column is not normalized.The buliding blocks are out of the normalized curve.

# %%
sns.distplot(df['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %% [markdown]
# The data of this column is not normalized.The buliding blocks are out of the normalized curve.

# %%
sns.distplot(df['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# The data of this column is not normalized.The buliding blocks are out of the normalized curve.

# %% [markdown]
# The normal distribution shows that the data is skewed.

# %% [markdown]
# Removing the skewness

# %%
from scipy.stats import boxcox
#0--->log transform
#.5--->square root transform
df['R']=boxcox(df['R'],0)

# %%
df['R'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['H']=boxcox(df['H'],0)

# %%
df['H'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Not able to remove skewness from'CG'column and the value is small which can be avoided

# %%
df['SV']=boxcox(df['SV'],0)

# %%
df['SV'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['E']=boxcox(df['E'],0)

# %%
df['E'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
sns.pairplot(df)

# %% [markdown]
# # Correlation:

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.442824 -0.087947  0.035305  0.427797 -0.251118  0.307407
# R    0.442824  1.000000  0.338160  0.481809  0.566762 -0.045118  0.676426
# AB  -0.087947  0.338160  1.000000  0.740101  0.453370  0.435422 -0.066983
# H    0.035305  0.481809  0.740101  1.000000  0.566231  0.476581 -0.091320
# 2B   0.427797  0.566762  0.453370  0.566231  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.045118  0.435422  0.476581  0.220490  1.000000 -0.430915
# HR   0.307407  0.676426 -0.066983 -0.091320  0.056292 -0.430915  1.000000
# BB   0.484342  0.395825 -0.136414 -0.117853  0.302700 -0.454949  0.425691
# SO   0.111850 -0.030640 -0.106022 -0.400197 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081067  0.372618  0.415696  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.051796  0.316010  0.223396 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.049386  0.309686  0.251906 -0.235531  0.340225 -0.085922
# ...

# %% [markdown]
# corelation using heatmap

# %%
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outcome of correlation:

# %% [markdown]
# All the columns of the dataset are positively correlated with the target column.
# Maximum correlation-
# Minimum correlation-'SV'save column

# %% [markdown]
# Checking whether how much outliers are still there and if these outliers help in the testing of the model or nor.

# %% [markdown]
# Model without outliers is df andmodel with desired outliers is df_new:

# %% [markdown]
# Dividing the data into features nd vectors:

# %%
#independent features:
x=df_new.iloc[:,:-1]

#dependent fetures:
y=df_new.iloc[:,-1]

# %%
x.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV
# 0  56
# 1  45
# 2  38
# 3  37
# 4  35

# %%
x.shape
# Out:
# (29, 16)

# %%
y.head()
# Out:
# 0     88
# 1     86
# 2     79
# 3    101
# 4     86
# Name: E, dtype: int64

# %%
y.shape
# Out:
# (29,)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
x_train.shape
# Out:
# (20, 16)

# %%
y_train.shape
# Out:
# (20,)

# %%
lm=LinearRegression()

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-2.02589201e+01,  1.52930040e+01, -4.26325641e-14, -1.66977543e-13,
#        -8.03676664e+00,  3.68736014e+00, -4.44927186e+00, -7.25376767e+00,
#        -7.45749406e+00,  4.02894935e+00,  1.24943060e+02, -1.25891612e+02,
#        -8.31056423e+00,  2.08791482e+00,  2.46662048e+00,  1.63554224e+01])

# %%
lm.intercept_
# Out:
# 99.55197379623796

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %%
lm.score(x_train,y_train)
# Out:
# 0.8368132121847788

# %% [markdown]
# lm.score indicates that the model is working 84%well.

# %%
#predict the value
pred=lm.predict(x_test)
print('Predicted result price:',pred)
print('actual price',y_test)
# Out:
# Predicted result price: [140.19461664  90.38556097  81.67396669 123.47010657 117.1743578
#  104.49404404 103.0375188  122.27058695 116.30648162]
# actual price 28     92
# 17    111
# 13     94
# 23     90
# 9      97
# 10    119
# 22     77
# 0      88
# 27     86
# Name: E, dtype: int64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
print('error')

print('Mean absolute error:',mean_absolute_error(y_test,pred))
print('Mean squared error:',mean_squared_error(y_test,pred))

print('Root Mean Squared Error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# error
# Mean absolute error: 26.655566298789118
# Mean squared error: 823.1323461745752
# Root Mean Squared Error: 28.690283131655832

# %%
#r2 score
from sklearn.metrics import r2_score
print(r2_score(y_test,pred))
# Out:
# -4.591556528022525

# %% [markdown]
# # Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.38207890e+00,  9.62543504e-01,  0.00000000e+00,
#          0.00000000e+00,  1.68518793e+00,  1.00615029e+00,
#         -7.41927000e-01, -1.60519802e+00, -2.55061247e+00,
#          9.36131648e-01, -6.60978697e-01, -5.08052224e-01,
#         -5.09292146e-01, -3.07098204e-01, -7.87002186e-01,
#          1.53275292e+00],
#        [ 2.75098810e-01,  2.98863300e-01,  0.00000000e+00,
#          0.00000000e+00,  1.38197902e-01,  1.18522654e+00,
#         -1.09958425e-01, -4.62095970e-01,  9.36832915e-02,
#         -5.16377335e-01,  1.60225829e-01,  2.35800488e-01,
#          2.41440214e-01, -3.07098204e-01,  2.36736538e-01,
#          3.12020186e-01],
#        [ 8.15199217e-02, -3.12105130e-01,  0.00000000e+00,
#          0.00000000e+00,  1.90738550e+00, -2.28819392e-01,
#         -6.64354121e-01,  1.23209786e+00, -9.35611465e-01,
#          2.25038365e-01, -6.74967476e-01, -7.52213881e-01,
#         -6.42097599e-01,  2.01131531e+00, -2.52844176e-01,
#         -6.64136739e-01],
# ...
