# %% [markdown]
# # Census Income Project

# %%
import numpy as np
import pandas as pd
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Census Income Project.csv')

# %%
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (32560, 15)

# %% [markdown]
# There are 32560 rows and 15 columns.

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# # Checking the datatypes of the columns

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# # Checking null values

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# There are no null values present in the dataset.

# %% [markdown]
# # Heatmap for the representation of null values

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# The heatmap also shows the absence of null values.

# %% [markdown]
# # Summary Statistics

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# High values of standard deviation in Capital_gain and Capital loss column indicate that the range is high and the data is widely spread.

# %% [markdown]
# # Outliers

# %% [markdown]
# Using boxplot to check the presence of outliers.

# %% [markdown]
# Collective representation of outliers of all the columns using box plot

# %%
df.plot(kind='box',subplots=True,layout=(2,5))
# Out:
# Age                  AxesSubplot(0.125,0.536818;0.133621x0.343182)
# Fnlwgt            AxesSubplot(0.285345,0.536818;0.133621x0.343182)
# Education_num      AxesSubplot(0.44569,0.536818;0.133621x0.343182)
# Capital_gain      AxesSubplot(0.606034,0.536818;0.133621x0.343182)
# Capital_loss      AxesSubplot(0.766379,0.536818;0.133621x0.343182)
# Hours_per_week          AxesSubplot(0.125,0.125;0.133621x0.343182)
# dtype: object

# %% [markdown]
# Theabove representaion shows that outliers are present in all the columns.Lets plot them individually.

# %%
df['Age'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in this column.

# %%
df['Fnlwgt'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Outliers are present in this column.

# %%
df['Education_num'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ouliers are present inthis column.

# %%
df['Capital_gain'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ouliers are present inthis column.

# %%
df['Capital_loss'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ouliers are present inthis column.

# %%
df['Hours_per_week'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ouliers are present in this column.

# %% [markdown]
# Removal of outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-7cf6b58543cd> in <module>
#       1 from scipy.stats import zscore
# ----> 2 z=np.abs(zscore(df))
#       3 z
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/stats.py in zscore(a, axis, ddof, nan_policy)
#    2557             isconst = np.apply_along_axis(_isconst, axis, a)
#    2558     else:
# -> 2559         mn = a.mean(axis=axis, keepdims=True)
#    2560         std = a.std(axis=axis, ddof=ddof, keepdims=True)
#    2561         if axis is None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py in _mean(a, axis, dtype, out, keepdims, where)
#     178     ret = umr_sum(arr, axis, dtype, out, keepdims, where=where)
#     179     if isinstance(ret, mu.ndarray):
# --> 180         ret = um.true_divide(
#     181                 ret, rcount, out=ret, casting='unsafe', subok=False)
# ...

# %%
from sklearn.preprocessing import LabelEncoder
LE=LabelEncoder()
df['Age']=LE.fit_transform(df['Age'])

# %%
df['Fnlwgt']=LE.fit_transform(df['Fnlwgt'])
df['Education_num']=LE.fit_transform(df['Education_num'])
df['Capital_gain']=LE.fit_transform(df['Capital_gain'])
df['Capital_loss']=LE.fit_transform(df['Capital_loss'])
df['Hours_per_week']=LE.fit_transform(df['Hours_per_week'])

# %% [markdown]
# # Skewness

# %%
df.skew()
# Out:
# Age               0.555583
# Fnlwgt            0.063137
# Education_num    -0.311630
# Capital_gain      3.572186
# Capital_loss      5.266058
# Hours_per_week    0.069753
# dtype: float64

# %% [markdown]
# skewness threshold is taken as +/-0.65 and so there is high skewness in Capital_gain and capital_loss column.

# %% [markdown]
# Graphical representation of skewness

# %%
df['Age'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Skewness in this column is below the threshold value.

# %%
df['Fnlwgt'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# skewness is very small and falls below are threshold value.

# %%
df['Education_num'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# skewness is very small and falls below are threshold value.

# %%
df['Capital_gain'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# High skewness is present in this column.

# %%
df['Capital_loss'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# High skewness is present

# %%
df['Hours_per_week'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# small skewness is present in this column.

# %% [markdown]
# # Normal Distribution Curve:

# %%
sns.distplot(df['Age'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# Data is almost normally distributed.

# %%
sns.distplot(df['Fnlwgt'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fnlwgt', ylabel='Density'>

# %% [markdown]
# Data is normally distributed.

# %%
sns.distplot(df['Education_num'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Education_num', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed and all the building blocks lie outside the curve.

# %%
sns.distplot(df['Capital_gain'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Capital_gain', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed inthis column and the building blocks lie outside the curve.

# %%
sns.distplot(df['Capital_loss'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Capital_loss', ylabel='Density'>

# %% [markdown]
# Data is not normally distributed inthis column and the building blocks lie outside the curve.

# %%
sns.distplot(df['Hours_per_week'])
# Out:
# /Users/apple/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Hours_per_week', ylabel='Density'>

# %% [markdown]
# Data is not normaly distributed as building blocksare outside the curve.

# %% [markdown]
# All the above data indicate the presence of skewness

# %% [markdown]
# Removal of skewness

# %%
from scipy.stats import boxcox
#0--->log transform
#.5--->square root transform
df['Capital_loss']=boxcox(df['Capital_loss'],.5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-491b31ccf419> in <module>
#       2 #0--->log transform
#       3 #.5--->square root transform
# ----> 4 df['Capital_loss']=boxcox(df['Capital_loss'],.5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py in boxcox(x, lmbda, alpha)
#    1041
#    1042     if any(x <= 0):
# -> 1043         raise ValueError("Data must be positive.")
#    1044
#    1045     if lmbda is not None:  # single transformation
#
# ValueError: Data must be positive.

# %% [markdown]
# skewness cannot be removed as data is not positive

# %%
sns.pairplot(df)

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                      Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# Age             1.000000 -0.078466       0.036547      0.125916      0.065058
# Fnlwgt         -0.078466  1.000000      -0.042806     -0.004562     -0.009912
# Education_num   0.036547 -0.042806       1.000000      0.154387      0.084175
# Capital_gain    0.125916 -0.004562       0.154387      1.000000     -0.056966
# Capital_loss    0.065058 -0.009912       0.084175     -0.056966      1.000000
# Hours_per_week  0.069123 -0.019168       0.150098      0.101367      0.058826
#
#                 Hours_per_week
# Age                   0.069123
# Fnlwgt               -0.019168
# Education_num         0.150098
# Capital_gain          0.101367
# Capital_loss          0.058826
# Hours_per_week        1.000000

# %% [markdown]
# grahical representation of correlation

# %%
sns.heatmap(df.corr(),annot=True,linewidth=0.5,linecolor='black',fmt='.2f')
# Out:
# <AxesSubplot:>
